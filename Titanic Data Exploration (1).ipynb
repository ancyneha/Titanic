# %% [markdown]
# ## Titanic Data Exploration ##
#
# ***
#
# Over the past several weeks, you've learned the code about how to explore and manipulate a dataset. Now it's time to practice what you've learned on a real-world dataset.
#
# ***
#
# ### Titanic Dataset
#
# The titanic dataset holds information about the passengers on the titanic. This includes passenger name, characteristics, and if they survived the accident. The dataset has the following columns:
#
#     * pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
#     * survived = passenger survival; 1 = survived, 0 = did not survive
#     * name = passenger name
#     * sex = sex of passenger
#     * age = age of passenger
#     * sibsp = # of siblings / spouses aboard the Titanic
#     * parch = # of parents / children aboard the Titanic
#     * ticket = ticket number
#     * fare = fare paid by passenger
#     * cabin = passenger cabin
#     * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
#     * boat = lifeboat assignment
#     * body = recovered body number
#     * home dest = anticipated home destination
#
# If you need some additional motivation before starting, please visit: https://www.youtube.com/watch?v=3gK_2XdjOdY
#
# ### How to work through the dataset:
#
# Follow the prompts below to explore, manipulate, and visualize aspects of the dataset. Working with data takes time, so take your time as you start with a messy dataset and turn it into something that shows meaningful visualizations.
#
# ***

# %% [markdown]
# ### Import Libraries and Dataset
#
# * Review the entire notebook to determine what you will be expected to do - then, import the necessary libraries
# * Import the titanic.xlsx dataset

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats 
import statsmodels.formula.api as sm

# %%
df = pd.read_excel("titanic.xlsx")

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Determine the Characteristics of the Dataset
#
#    * How many columns are in this dataset?
#    * How many rows are in this dataset?
#    * What types of data are in each column? Does this make sense with that you know about that column?
#    * Which variables are numeric? Which variables are categorical? What other variables are left outside of these two groups?
#    * Which variable could be considered a 'dependent' variable?

# %%
df.info()
df.shape
# Dependent variable: Survived
#Numerical variables are: pclass, survived, age, sibsp, parch, ticket, fare,boat and body
#categorical variables are: name, sex, embarked,cabin and home.dest
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
#  14  age group  1046 non-null   category
# dtypes: category(1), float64(3), int64(4), object(7)
# memory usage: 144.8+ KB
# (1309, 15)

# %% [markdown]
# ### Identify the Missing Data in the Dataset
#
#    * Is there any missing data?
#    * Which columns have any missing data?
#    * Which column has the most missing information? Which column has the least?

# %%
df.isnull().sum()
# the columns age, cabin, embarked, boat, body, fare, and home.dest
#the column body has the maximum (1188) missing values and fare has the minimum (1) missing values.
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# age group     263
# dtype: int64

# %% [markdown]
# ### Handling the Missing Data in the Dataset
#
#    * Remove the columns with excessive missing data (any column missing greater than 500 rows)
#    * When there is very little missing data, we can make replacements. Replace the missing data for the "embarked" column with the most common embarkation point.
#    * Replace the missing data in "fare" with the average fare of the entire sample.
#    * Remove the rows in the dataset that has missing "age" data.
#    * Recheck is there is any data missing in the dataset.

# %%
df.drop(columns = ["home.dest", "cabin", "boat", "body"], inplace = True)


df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare embarked age group
# 0  29.0000      0      0   24160  211.3375        S     adult
# 1   0.9167      1      2  113781  151.5500        S    infant
# 2   2.0000      1      2  113781  151.5500        S     child
# 3  30.0000      1      2  113781  151.5500        S     adult
# 4  25.0000      1      2  113781  151.5500        S     adult

# %%
df["embarked"].fillna("S", inplace = True)

df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked age group
# 0     female  29.0000      0      0   24160  211.3375        S     adult
# 1       male   0.9167      1      2  113781  151.5500        S    infant
# 2     female   2.0000      1      2  113781  151.5500        S     child
# 3       male  30.0000      1      2  113781  151.5500        S     adult
# 4     female  25.0000      1      2  113781  151.5500        S     adult
# ...      ...      ...    ...    ...     ...       ...      ...       ...
# 1304  female  14.5000      1      0    2665   14.4542        C      teen
# 1305  female      NaN      1      0    2665   14.4542        C       NaN
# 1306    male  26.5000      0      0    2656    7.2250        C     adult
# 1307    male  27.0000      0      0    2670    7.2250        C     adult
# 1308    male  29.0000      0      0  315082    7.8750        S     adult
#
# [1309 rows x 11 columns]

# %%
print(df["fare"].mean())

df["fare"].fillna(df["fare"].mean(), inplace = True)

df
# Out:
# 33.29547928134572
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked age group
# 0     female  29.0000      0      0   24160  211.3375        S     adult
# 1       male   0.9167      1      2  113781  151.5500        S    infant
# 2     female   2.0000      1      2  113781  151.5500        S     child
# 3       male  30.0000      1      2  113781  151.5500        S     adult
# 4     female  25.0000      1      2  113781  151.5500        S     adult
# ...      ...      ...    ...    ...     ...       ...      ...       ...
# 1304  female  14.5000      1      0    2665   14.4542        C      teen
# 1305  female      NaN      1      0    2665   14.4542        C       NaN
# 1306    male  26.5000      0      0    2656    7.2250        C     adult
# 1307    male  27.0000      0      0    2670    7.2250        C     adult
# 1308    male  29.0000      0      0  315082    7.8750        S     adult
#
# [1309 rows x 11 columns]

# %%
df.dropna(inplace = True)

df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare embarked age group
# 0  29.0000      0      0   24160  211.3375        S     adult
# 1   0.9167      1      2  113781  151.5500        S    infant
# 2   2.0000      1      2  113781  151.5500        S     child
# 3  30.0000      1      2  113781  151.5500        S     adult
# 4  25.0000      1      2  113781  151.5500        S     adult

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1046 non-null   int64
#  1   survived   1046 non-null   int64
#  2   name       1046 non-null   object
#  3   sex        1046 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1046 non-null   int64
#  6   parch      1046 non-null   int64
#  7   ticket     1046 non-null   object
#  8   fare       1046 non-null   float64
#  9   embarked   1046 non-null   object
#  10  age group  1046 non-null   category
# dtypes: category(1), float64(2), int64(4), object(4)
# memory usage: 91.1+ KB

# %% [markdown]
# ### Creating Columns and Replacing Labels
#
#    * Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)
#    * Create a new column called "Titanic Passenger" and make all values 1
#    * Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.
#    * Create a column called "Travel Alone" - this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.
#    * Create a column called "Has Caregiver" - this column should have a value of 1 if a passenger is less than 13-years old AND the passenger is traveling with at least one family member, otherwise the value should be 0.
#    * Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
#    * Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior). You can use bins to complete this (or any other method you like). You define the cutoff points for each group you create.
#
# After create new columns, replace the basic coding "0/1" with meaningful labels.

# %%
df["pclass"].replace([1, 2, 3], ["First Class", "Second Class", "Third Class"], inplace = True)

df
# Out:
#            pclass  survived                                             name  \
# 0     First Class         1                    Allen, Miss. Elisabeth Walton
# 1     First Class         1                   Allison, Master. Hudson Trevor
# 2     First Class         0                     Allison, Miss. Helen Loraine
# 3     First Class         0             Allison, Mr. Hudson Joshua Creighton
# 4     First Class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  Third Class         0                             Youseff, Mr. Gerious
# 1304  Third Class         0                             Zabour, Miss. Hileni
# 1306  Third Class         0                        Zakarian, Mr. Mapriededer
# 1307  Third Class         0                              Zakarian, Mr. Ortin
# 1308  Third Class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked age group
# 0     female  29.0000      0      0   24160  211.3375        S     adult
# 1       male   0.9167      1      2  113781  151.5500        S    infant
# 2     female   2.0000      1      2  113781  151.5500        S     child
# 3       male  30.0000      1      2  113781  151.5500        S     adult
# 4     female  25.0000      1      2  113781  151.5500        S     adult
# ...      ...      ...    ...    ...     ...       ...      ...       ...
# 1301    male  45.5000      0      0    2628    7.2250        C     adult
# 1304  female  14.5000      1      0    2665   14.4542        C      teen
# 1306    male  26.5000      0      0    2656    7.2250        C     adult
# 1307    male  27.0000      0      0    2670    7.2250        C     adult
# 1308    male  29.0000      0      0  315082    7.8750        S     adult
#
# [1046 rows x 11 columns]

# %%
df["survived"].replace([1, 0], ["survived", "did not survived"], inplace = True)

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare embarked age group
# 0         0   24160  211.3375        S     adult
# 1         2  113781  151.5500        S    infant
# 2         2  113781  151.5500        S     child
# 3         2  113781  151.5500        S     adult
# 4         2  113781  151.5500        S     adult
# ...     ...     ...       ...      ...       ...
# 1301      0    2628    7.2250        C     adult
# 1304      0    2665   14.4542        C      teen
# 1306      0    2656    7.2250        C     adult
# 1307      0    2670    7.2250        C     adult
# 1308      0  315082    7.8750        S     adult
#
# [1046 rows x 11 columns]

# %%
df["embarked"].replace(["c", "Q", "S"], ["Cherbourg", "Queenstown", "Southampton"], inplace = True)

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group
# 0         0   24160  211.3375  Southampton     adult
# 1         2  113781  151.5500  Southampton    infant
# 2         2  113781  151.5500  Southampton     child
# 3         2  113781  151.5500  Southampton     adult
# 4         2  113781  151.5500  Southampton     adult
# ...     ...     ...       ...          ...       ...
# 1301      0    2628    7.2250            C     adult
# 1304      0    2665   14.4542            C      teen
# 1306      0    2656    7.2250            C     adult
# 1307      0    2670    7.2250            C     adult
# 1308      0  315082    7.8750  Southampton     adult
#
# [1046 rows x 11 columns]

# %%
df["Titanic Passenger"] = 1

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
# [1046 rows x 12 columns]

# %%
df["Family Size"] = df["sibsp"] + df["parch"] + 1

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size
# 0               1
# 1               4
# 2               4
# 3               4
# 4               4
# ...           ...
# 1301            1
# 1304            2
# 1306            1
# 1307            1
# 1308            1
#
# [1046 rows x 13 columns]

# %%
df["Travel Alone"] = np.where((df["Family Size"] == 1), 1, 0)

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size  Travel Alone
# 0               1             1
# 1               4             0
# 2               4             0
# 3               4             0
# 4               4             0
# ...           ...           ...
# 1301            1             1
# 1304            2             0
# 1306            1             1
# 1307            1             1
# 1308            1             1
#
# [1046 rows x 14 columns]

# %%
df["Has caregiver"] = np.where((df["age"] < 13) & (df["Family Size"] >= 2), 1, 0)

df.head()
# Out:
#         pclass          survived  \
# 0  First Class          survived
# 1  First Class          survived
# 2  First Class  did not survived
# 3  First Class  did not survived
# 4  First Class  did not survived
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master. Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss. Helen Loraine  female   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0      0   24160  211.3375  Southampton     adult                  1
# 1      2  113781  151.5500  Southampton    infant                  1
# 2      2  113781  151.5500  Southampton     child                  1
# 3      2  113781  151.5500  Southampton     adult                  1
# 4      2  113781  151.5500  Southampton     adult                  1
#
#    Family Size  Travel Alone  Has caregiver
# 0            1             1              0
# 1            4             0              1
# 2            4             0              1
# 3            4             0              0
# 4            4             0              0

# %%
df["crew"] = np.where((df["fare"]== 0), 1, 0)
df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size  Travel Alone  Has caregiver  crew
# 0               1             1              0     0
# 1               4             0              1     0
# 2               4             0              1     0
# 3               4             0              0     0
# 4               4             0              0     0
# ...           ...           ...            ...   ...
# 1301            1             1              0     0
# 1304            2             0              0     0
# 1306            1             1              0     0
# 1307            1             1              0     0
# 1308            1             1              0     0
#
# [1046 rows x 16 columns]

# %%
### convert the age into different groups

#0 - 1  = infant
#1.1 - 12 = child
#12.1 - 19 = teen
#19.1 - 55 = adult
#55.1 - 120 = seniors
#### STEP 1: create the bin limits ####

bins = [0, 1, 12, 19, 55, 120]

## the bin limits are the cutoff points for the values
## each number shown is the cutoff for a specific group (0-60, 60.1 - 70, 70.1 - 80...)

bin_labels = ["infant", "child", "teen", "adult", "seniors"]

## the bin labels are the group names that will be created
## there should always be one less group than bins

#### STEP 2: apply your bins to a specific column (or create new column) in dataset  ####
## new column = pd.cut(column to apply to, bin cutoff list, labels = list of bin labels)
# pd.cut function segments and organizes values into the appropriate bin

df["age group"] = pd.cut(df["age"], bins, labels = bin_labels)


#### STEP 3: check changes  ####

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size  Travel Alone  Has caregiver  crew
# 0               1             1              0     0
# 1               4             0              1     0
# 2               4             0              1     0
# 3               4             0              0     0
# 4               4             0              0     0
# ...           ...           ...            ...   ...
# 1301            1             1              0     0
# 1304            2             0              0     0
# 1306            1             1              0     0
# 1307            1             1              0     0
# 1308            1             1              0     0
#
# [1046 rows x 16 columns]

# %%
df["Travel Alone"].replace([1, 0], ["Travelling alone", "Travelling with family"], inplace = True)

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size            Travel Alone  Has caregiver  crew
# 0               1        Travelling alone              0     0
# 1               4  Travelling with family              1     0
# 2               4  Travelling with family              1     0
# 3               4  Travelling with family              0     0
# 4               4  Travelling with family              0     0
# ...           ...                     ...            ...   ...
# 1301            1        Travelling alone              0     0
# 1304            2  Travelling with family              0     0
# 1306            1        Travelling alone              0     0
# 1307            1        Travelling alone              0     0
# 1308            1        Travelling alone              0     0
#
# [1046 rows x 16 columns]

# %%
df["Has caregiver"].replace([1, 0], ["Passenger < 13 years and travel with family", "Passenger >= 13 and travel alone"], 
                                     inplace = True)

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size            Travel Alone  \
# 0               1        Travelling alone
# 1               4  Travelling with family
# 2               4  Travelling with family
# 3               4  Travelling with family
# 4               4  Travelling with family
# ...           ...                     ...
# 1301            1        Travelling alone
# 1304            2  Travelling with family
# 1306            1        Travelling alone
# 1307            1        Travelling alone
# 1308            1        Travelling alone
#
#                                     Has caregiver  crew
# 0                Passenger >= 13 and travel alone     0
# 1     Passenger < 13 years and travel with family     0
# 2     Passenger < 13 years and travel with family     0
# 3                Passenger >= 13 and travel alone     0
# 4                Passenger >= 13 and travel alone     0
# ...                                           ...   ...
# 1301             Passenger >= 13 and travel alone     0
# 1304             Passenger >= 13 and travel alone     0
# 1306             Passenger >= 13 and travel alone     0
# 1307             Passenger >= 13 and travel alone     0
# 1308             Passenger >= 13 and travel alone     0
#
# [1046 rows x 16 columns]

# %%
df["crew"].replace([1, 0], ["Paid 0 dollar for ticket", "Paid for ticket"], inplace = True)

df
# Out:
#            pclass          survived  \
# 0     First Class          survived
# 1     First Class          survived
# 2     First Class  did not survived
# 3     First Class  did not survived
# 4     First Class  did not survived
# ...           ...               ...
# 1301  Third Class  did not survived
# 1304  Third Class  did not survived
# 1306  Third Class  did not survived
# 1307  Third Class  did not survived
# 1308  Third Class  did not survived
#
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1301                             Youseff, Mr. Gerious    male  45.5000      0
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
#       parch  ticket      fare     embarked age group  Titanic Passenger  \
# 0         0   24160  211.3375  Southampton     adult                  1
# 1         2  113781  151.5500  Southampton    infant                  1
# 2         2  113781  151.5500  Southampton     child                  1
# 3         2  113781  151.5500  Southampton     adult                  1
# 4         2  113781  151.5500  Southampton     adult                  1
# ...     ...     ...       ...          ...       ...                ...
# 1301      0    2628    7.2250            C     adult                  1
# 1304      0    2665   14.4542            C      teen                  1
# 1306      0    2656    7.2250            C     adult                  1
# 1307      0    2670    7.2250            C     adult                  1
# 1308      0  315082    7.8750  Southampton     adult                  1
#
#       Family Size            Travel Alone  \
# 0               1        Travelling alone
# 1               4  Travelling with family
# 2               4  Travelling with family
# 3               4  Travelling with family
# 4               4  Travelling with family
# ...           ...                     ...
# 1301            1        Travelling alone
# 1304            2  Travelling with family
# 1306            1        Travelling alone
# 1307            1        Travelling alone
# 1308            1        Travelling alone
#
#                                     Has caregiver             crew
# 0                Passenger >= 13 and travel alone  Paid for ticket
# 1     Passenger < 13 years and travel with family  Paid for ticket
# 2     Passenger < 13 years and travel with family  Paid for ticket
# 3                Passenger >= 13 and travel alone  Paid for ticket
# 4                Passenger >= 13 and travel alone  Paid for ticket
# ...                                           ...              ...
# 1301             Passenger >= 13 and travel alone  Paid for ticket
# 1304             Passenger >= 13 and travel alone  Paid for ticket
# 1306             Passenger >= 13 and travel alone  Paid for ticket
# 1307             Passenger >= 13 and travel alone  Paid for ticket
# 1308             Passenger >= 13 and travel alone  Paid for ticket
#
# [1046 rows x 16 columns]

# %% [markdown]
# ### Determine Frequencies of Groups
#
# * How many passengers fall into each category? Determine how many passengers fall into each group for <b>each</b> categorical vairable (including the ones you just created).

# %%
df["pclass"].value_counts()
# Out:
# Third Class     501
# First Class     284
# Second Class    261
# Name: pclass, dtype: int64

# %%
df["survived"].value_counts()
# Out:
# did not survived    619
# survived            427
# Name: survived, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      658
# female    388
# Name: sex, dtype: int64

# %%
df["sibsp"].value_counts()
# Out:
# 0    685
# 1    280
# 2     36
# 4     22
# 3     16
# 5      6
# 8      1
# Name: sibsp, dtype: int64

# %%
df["parch"].value_counts()
# Out:
# 0    768
# 1    160
# 2     97
# 3      8
# 5      6
# 4      5
# 6      2
# Name: parch, dtype: int64

# %%
df["embarked"].value_counts()
# Out:
# Southampton    784
# C              212
# Queenstown      50
# Name: embarked, dtype: int64

# %%
df["age group"].value_counts()
# Out:
# adult      762
# teen       131
# child       72
# seniors     59
# infant      22
# Name: age group, dtype: int64

# %%
df["Travel Alone"].value_counts()
# Out:
# Travelling alone          590
# Travelling with family    456
# Name: Travel Alone, dtype: int64

# %%
df["Has caregiver"].value_counts()
# Out:
# Passenger >= 13 and travel alone               955
# Passenger < 13 years and travel with family     91
# Name: Has caregiver, dtype: int64

# %%
df["crew"].value_counts()
# Out:
# Paid for ticket             1038
# Paid 0 dollar for ticket       8
# Name: crew, dtype: int64

# %% [markdown]
# ### Determine the Distribution of Numeric Data
#
# * What are the summary statistics for <b>each</b> numeric variable in the dataset? Summary statistics include:
#     * Mean
#     * Median
#     * Mode
#     * Standard Deviation
#     * Range

# %%
df["age"].mean()
# Out:
# 29.8811345124283

# %%
df["age"].median()
# Out:
# 28.0

# %%
df["age"].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
df["age"].std()
# Out:
# 14.413499699923594

# %%
age_range = df['age'].max() - df['age'].min()

print(age_range)
# Out:
# 79.8333

# %%
df["fare"].mean()
# Out:
# 36.68283879472418

# %%
df["fare"].median()
# Out:
# 15.8

# %%
df["fare"].mode()
# Out:
# 0    13.0
# dtype: float64

# %%
df["fare"].std()
# Out:
# 55.70595916349577

# %%
fare_range = df['fare'].max() - df['fare'].min()

print(fare_range)
# Out:
# 512.3292

# %%
df["Family Size"].mean()
# Out:
# 1.9235181644359465

# %%
df["Family Size"].median()
# Out:
# 1.0

# %%
df["Family Size"].mode()
# Out:
# 0    1
# dtype: int64

# %%
df["Family Size"].std()
# Out:
# 1.4528906850592564

# %%
df["parch"].mean()
# Out:
# 0.42065009560229444

# %%
df["parch"].median()
# Out:
# 0.0

# %%
df["parch"].mode()
# Out:
# 0    0
# dtype: int64

# %%
df["parch"].std()
# Out:
# 0.8397504516166859

# %%
parch_range = df['parch'].max() - df['parch'].min()

print(parch_range)
# Out:
# 6

# %%
df["sibsp"].mean()
# Out:
# 0.502868068833652

# %%
df["sibsp"].median()
# Out:
# 0.0

# %%
df["sibsp"].mode()
# Out:
# 0    0
# dtype: int64

# %%
df["sibsp"].std()
# Out:
# 0.912167299664662

# %% [markdown]
# ### Relationships between Variables
#
# * Determine the relationship between each variable and the variable "survived". This is our primary variable of interest -- did this passenger survive the accident? Did the characteristics of the passenger have any relationship with their survival?
#     * <b>pclass</b>: how many survivors are in each passenger class? does a pattern emerge? which class has the most survivors? which has the least?
#     * <b>sex</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>age</b>: how does the average age of the passenger differ based on survival group?
#     * <b>age group</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>family size</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>travel alone</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>crew</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>has caregiver</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>fare</b>: how does the average fare the passenger paid differ based on survival group?
#     * <b>embarked</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#
# Based on what you learn working through this section, make (2) statements about what characteristics of passenger most influenced their survival.

# %%
df.drop(["Titanic Passenger", "name", "sibsp", "parch", "ticket"], axis = 1, inplace = True)

# %%
df
# Out:
#            pclass          survived     sex      age      fare     embarked  \
# 0     First Class          survived  female  29.0000  211.3375  Southampton
# 1     First Class          survived    male   0.9167  151.5500  Southampton
# 2     First Class  did not survived  female   2.0000  151.5500  Southampton
# 3     First Class  did not survived    male  30.0000  151.5500  Southampton
# 4     First Class  did not survived  female  25.0000  151.5500  Southampton
# ...           ...               ...     ...      ...       ...          ...
# 1301  Third Class  did not survived    male  45.5000    7.2250            C
# 1304  Third Class  did not survived  female  14.5000   14.4542            C
# 1306  Third Class  did not survived    male  26.5000    7.2250            C
# 1307  Third Class  did not survived    male  27.0000    7.2250            C
# 1308  Third Class  did not survived    male  29.0000    7.8750  Southampton
#
#      age group  Family Size            Travel Alone  \
# 0        adult            1        Travelling alone
# 1       infant            4  Travelling with family
# 2        child            4  Travelling with family
# 3        adult            4  Travelling with family
# 4        adult            4  Travelling with family
# ...        ...          ...                     ...
# 1301     adult            1        Travelling alone
# 1304      teen            2  Travelling with family
# 1306     adult            1        Travelling alone
# 1307     adult            1        Travelling alone
# 1308     adult            1        Travelling alone
#
#                                     Has caregiver             crew
# 0                Passenger >= 13 and travel alone  Paid for ticket
# 1     Passenger < 13 years and travel with family  Paid for ticket
# 2     Passenger < 13 years and travel with family  Paid for ticket
# 3                Passenger >= 13 and travel alone  Paid for ticket
# 4                Passenger >= 13 and travel alone  Paid for ticket
# ...                                           ...              ...
# 1301             Passenger >= 13 and travel alone  Paid for ticket
# 1304             Passenger >= 13 and travel alone  Paid for ticket
# 1306             Passenger >= 13 and travel alone  Paid for ticket
# 1307             Passenger >= 13 and travel alone  Paid for ticket
# 1308             Passenger >= 13 and travel alone  Paid for ticket
#
# [1046 rows x 11 columns]

# %%
## new library alert! ##

## Import the StatsModels library for our regression analyses

import statsmodels.formula.api as sm

# %%
## create the regression model
result = sm.ols('survived ~ pclass + sex + age + agegroup + fare + embarked + Hascaregiver + crew', data = df).fit()

## print the regression model summary
result.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~\anaconda3\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'agegroup' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-106-92fb3372ed3a> in <module>
#       1 ## create the regression model
# ----> 2 result = sm.ols('survived ~ pclass + sex + age + agegroup + fare + embarked + Hascaregiver + crew', data = df).fit()
#       3
#       4 ## print the regression model summary
#       5 result.summary()
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     167             missing = 'raise'
#     168
# --> 169         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     170                                   missing=missing)
#     171         ((endog, exog), missing_idx, design_info) = tmp
#
# ~\anaconda3\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# ~\anaconda3\lib\site-packages\patsy\highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# ~\anaconda3\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# ~\anaconda3\lib\site-packages\patsy\highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64     if isinstance(formula_like, ModelDesc):
#      65         assert isinstance(eval_env, EvalEnvironment)
# ---> 66         return design_matrix_builders([formula_like.lhs_termlist,
#      67                                        formula_like.rhs_termlist],
#      68                                       data_iter_maker,
#
# ~\anaconda3\lib\site-packages\patsy\build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     691     # on some data to find out what type of data they return.
#     692     (num_column_counts,
# --> 693      cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
#
# ~\anaconda3\lib\site-packages\patsy\build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# ~\anaconda3\lib\site-packages\patsy\eval.py in eval(self, memorize_state, data)
#     562
#     563     def eval(self, memorize_state, data):
# --> 564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
#     566                           data)
#
# ~\anaconda3\lib\site-packages\patsy\eval.py in _eval(self, code, memorize_state, data)
#     545     def _eval(self, code, memorize_state, data):
#     546         inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 547         return call_and_wrap_exc("Error evaluating factor",
#     548                                  self,
#     549                                  memorize_state["eval_env"].eval,
#
# ~\anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# ~\anaconda3\lib\site-packages\patsy\compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'agegroup' is not defined
#     survived ~ pclass + sex + age + agegroup + fare + embarked + Hascaregiver + crew
#                                     ^^^^^^^^

# %%
## create the regression model
result = sm.ols('grade ~ hours + age + exercise + C(gender)', data = df).fit()

## print the regression model summary
result.summary()

# %% [markdown]
# ### Visualize your Results
#
# * Using the most interesting (from your POV) results from the above section, create (3) visualizations to illustrate the results.
# * Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?
# * Create a violin plot to show the distribution of age across passenger class.
